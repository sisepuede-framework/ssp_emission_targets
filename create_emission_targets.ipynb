# %%
import pandas as pd
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
DATA_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "data")
OUTPUT_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "output")

# %% [markdown]
# ## Load Inventory and Crosswalk Files

# %%
# Set up file names
INVENTORY_FILE = os.path.join(DATA_DIR_PATH, "CSC-GHG_emissions-April2024_to_calibrate.csv")
CROSSWALK_FILE = os.path.join(DATA_DIR_PATH, "sisepuede_edgar_active_crosswalk.csv")

# Set up region name, year, and iso3
REGION = "libya"
YEAR = 2022
ISO3 = "LBY"

# %%
inventory_df = pd.read_csv(INVENTORY_FILE, encoding='latin1')
crosswalk_df = pd.read_csv(CROSSWALK_FILE)

# %%
inventory_df.head()
# Out:
#   Code Country EDGAR Country Code Income group Lending category  \
# 0  ABW   Aruba                ABW  High income              NaN
# 1  ABW   Aruba                ABW  High income              NaN
# 2  ABW   Aruba                ABW  High income              NaN
# 3  ABW   Aruba                ABW  High income              NaN
# 4  ABW   Aruba                ABW  High income              NaN
#
#                       Region CSC Sector          CSC Subsector  Gas   Units  \
# 0  Latin America & Caribbean     Energy          EN - Building  CH4  MtCO2e
# 1  Latin America & Caribbean     Energy          EN - Building  CO2  MtCO2e
# 2  Latin America & Caribbean     Energy          EN - Building  N2O  MtCO2e
# 3  Latin America & Caribbean     Energy  EN - Electricity/Heat  CH4  MtCO2e
# 4  Latin America & Caribbean     Energy  EN - Electricity/Heat  CO2  MtCO2e
#
#    ...      2013      2014      2015      2016      2017      2018      2019  \
# 0  ...  0.000554  0.000538  0.000500  0.000570  0.000542  0.000574  0.000471
# 1  ...  0.047090  0.037332  0.035079  0.039403  0.035488  0.044616  0.050051
# 2  ...  0.000160  0.000138  0.000130  0.000137  0.000135  0.000235  0.000264
# 3  ...  0.000114  0.000120  0.000126  0.000127  0.000122  0.000132  0.000156
# 4  ...  0.213816  0.222204  0.229352  0.239740  0.223555  0.232325  0.274290
#
#        2020      2021      2022
# 0  0.000616  0.000617  0.000622
# 1  0.044068  0.042466  0.044068
# 2  0.000240  0.000234  0.000241
# 3  0.000135  0.000132  0.000136
# 4  0.232537  0.224081  0.232537
#
# [5 rows x 33 columns]

# %%
crosswalk_df.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  ch4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  co2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  n2o  Agriculture      AG - Crops                AG - Crops
# 3      lvst  ch4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  ch4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars  ignore  \
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...     NaN
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...     NaN
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...     NaN
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...     NaN
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...     NaN
#
#                                  note  \
# 0  may include fertilizer application
# 1         may include liming and urea
# 2  may include fertilizer application
# 3                                 NaN
# 4                                 NaN
#
#    need_better_information_on_what_is_contained
# 0                                           1.0
# 1                                           1.0
# 2                                           1.0
# 3                                           NaN
# 4                                           NaN

# %% [markdown]
# ## Cleaning dataframes before merge

# %%
# Filter inventory for the specified region and year
inventory_region_year_df = inventory_df[(inventory_df['Code'] == ISO3)][["Code", "CSC Subsector", "Gas", str(YEAR)]]
inventory_region_year_df = inventory_region_year_df.rename(columns={str(YEAR): ISO3})
inventory_region_year_df.head()
# Out:
#      Code   CSC Subsector  Gas       LBY
# 3057  LBY  AG - Livestock  CH4  1.909586
# 3058  LBY  AG - Livestock  N2O  0.007607
# 3059  LBY      AG - Crops  CH4  0.000293
# 3060  LBY      AG - Crops  CO2  0.015880
# 3061  LBY      AG - Crops  N2O  0.759204

# %%
# Make Gas column Uppercase for merging
crosswalk_df['Gas'] = crosswalk_df['Gas'].str.upper()
inventory_region_year_df['Gas'] = inventory_region_year_df['Gas'].str.upper()

# %%
crosswalk_df = crosswalk_df.drop(columns=["ignore", "note", "need_better_information_on_what_is_contained"])
crosswalk_df.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  CH4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  CO2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  N2O  Agriculture      AG - Crops                AG - Crops
# 3      lvst  CH4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  CH4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...

# %%
# Let's create a id column to merge on
inventory_region_year_df["id"] = inventory_region_year_df["CSC Subsector"] + " - "+ inventory_region_year_df["Gas"]
crosswalk_df["id"] = crosswalk_df["Edgar_Subsector"] + " - " + crosswalk_df["Gas"]

# %%
inventory_region_year_df.head()
# Out:
#      Code   CSC Subsector  Gas       LBY                    id
# 3057  LBY  AG - Livestock  CH4  1.909586  AG - Livestock - CH4
# 3058  LBY  AG - Livestock  N2O  0.007607  AG - Livestock - N2O
# 3059  LBY      AG - Crops  CH4  0.000293      AG - Crops - CH4
# 3060  LBY      AG - Crops  CO2  0.015880      AG - Crops - CO2
# 3061  LBY      AG - Crops  N2O  0.759204      AG - Crops - N2O

# %%
crosswalk_df.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  CH4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  CO2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  N2O  Agriculture      AG - Crops                AG - Crops
# 3      lvst  CH4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  CH4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars                    id
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...      AG - Crops - CH4
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...      AG - Crops - CO2
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...      AG - Crops - N2O
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  AG - Livestock - CH4
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  AG - Livestock - CH4

# %%
# Check for duplicated ids in both dataframes
print("Duplicated IDs in inventory_region_year_df:", inventory_region_year_df['id'].duplicated().sum())
print("Duplicated IDs in crosswalk_df:", crosswalk_df['id'].duplicated().sum())
# Out:
# Duplicated IDs in inventory_region_year_df: 0
# Duplicated IDs in crosswalk_df: 2

# %% [markdown]
# ## Merge Data

# %%
inventory_region_year_df.columns
# Out:
# Index(['Code', 'CSC Subsector', 'Gas', 'LBY', 'id'], dtype='object')

# %%
merged_df = pd.merge(crosswalk_df, inventory_region_year_df[["id", ISO3]], how='left', on='id')
merged_df.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  CH4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  CO2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  N2O  Agriculture      AG - Crops                AG - Crops
# 3      lvst  CH4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  CH4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars                    id  \
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...      AG - Crops - CH4
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...      AG - Crops - CO2
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...      AG - Crops - N2O
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  AG - Livestock - CH4
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  AG - Livestock - CH4
#
#         LBY
# 0  0.000293
# 1  0.015880
# 2  0.759204
# 3  1.909586
# 4  1.909586

# %%
# Check duplicated ids
duplicated_ids = merged_df[merged_df['id'].duplicated(keep=False)]
duplicated_ids
# Out:
#    Subsector  Gas                             Edgar_Sector  \
# 3       lvst  CH4                              Agriculture
# 4       lsmm  CH4                              Agriculture
# 62      frst  CO2  Land Use, Land Use Change, and Forestry
# 63      frst  CO2  Land Use, Land Use Change, and Forestry
#
#          Edgar_Subsector           Edgar_Subsector_Synthetic  \
# 3         AG - Livestock                      AG - Livestock
# 4         AG - Livestock                      AG - Livestock
# 62  LULUCF - Forest Land       LULUCF - Forest Land Removals
# 63  LULUCF - Forest Land  LULUCF - Forest Land Sequestration
#
#                                                  Vars  \
# 3   emission_co2e_ch4_lvst_entferm_buffalo:emissio...
# 4   emission_co2e_ch4_lsmm_anaerobic_digester:emis...
# 62  emission_co2e_co2_entc_bmass_processing_and_re...
# 63  emission_co2e_co2_frst_sequestration_mangroves...
#
#                             id       LBY
# 3         AG - Livestock - CH4  1.909586
# 4         AG - Livestock - CH4  1.909586
# 62  LULUCF - Forest Land - CO2       NaN
# 63  LULUCF - Forest Land - CO2       NaN

# %% [markdown]
# ## Deal with NaNs

# %%
# merged_df[merged_df[ISO3].isna()]

# %% [markdown]
# ### Check IPPU

# %%
inventory_region_year_df[inventory_region_year_df["CSC Subsector"] == "IN - Industrial Processes"]
# Out:
#      Code              CSC Subsector  Gas       LBY  \
# 3077  LBY  IN - Industrial Processes  CH4  0.003465
# 3078  LBY  IN - Industrial Processes  CO2  2.499458
# 3079  LBY  IN - Industrial Processes  HFC  4.191501
# 3080  LBY  IN - Industrial Processes  N2O  0.360349
# 3081  LBY  IN - Industrial Processes  SF6  0.560506
#
#                                    id
# 3077  IN - Industrial Processes - CH4
# 3078  IN - Industrial Processes - CO2
# 3079  IN - Industrial Processes - HFC
# 3080  IN - Industrial Processes - N2O
# 3081  IN - Industrial Processes - SF6

# %%
pd.merge(crosswalk_df[crosswalk_df["Edgar_Subsector"] == "IN - Industrial Processes"], 
        inventory_region_year_df[inventory_region_year_df["CSC Subsector"] == "IN - Industrial Processes"],
        how="inner",
        on="id"
        )
# Out:
#   Subsector Gas_x          Edgar_Sector            Edgar_Subsector  \
# 0      ippu   CH4  Industrial Processes  IN - Industrial Processes
# 1      ippu   CO2  Industrial Processes  IN - Industrial Processes
# 2      ippu   N2O  Industrial Processes  IN - Industrial Processes
# 3      ippu   SF6  Industrial Processes  IN - Industrial Processes
#
#    Edgar_Subsector_Synthetic  \
# 0  IN - Industrial Processes
# 1  IN - Industrial Processes
# 2  IN - Industrial Processes
# 3  IN - Industrial Processes
#
#                                                 Vars  \
# 0  emission_co2e_ch4_ippu_production_chemicals:em...
# 1  emission_co2e_co2_ippu_product_use_product_use...
# 2  emission_co2e_n2o_ippu_production_chemicals:em...
# 3  emission_co2e_sf6_ippu_production_chemicals:em...
#
#                                 id Code              CSC Subsector Gas_y  \
# 0  IN - Industrial Processes - CH4  LBY  IN - Industrial Processes   CH4
# 1  IN - Industrial Processes - CO2  LBY  IN - Industrial Processes   CO2
# 2  IN - Industrial Processes - N2O  LBY  IN - Industrial Processes   N2O
# 3  IN - Industrial Processes - SF6  LBY  IN - Industrial Processes   SF6
#
#         LBY
# 0  0.003465
# 1  2.499458
# 2  0.360349
# 3  0.560506

# %%
# Get the emission value for FC gases
fc_gas_total = inventory_region_year_df[(inventory_region_year_df["CSC Subsector"] == "IN - Industrial Processes") & (inventory_region_year_df["Gas"] == "HFC")][ISO3].values[0]
fc_gas_total
# Out:
# np.float64(4.191500967)

# %%
merged_df.loc[(merged_df["Edgar_Subsector"] == "IN - Industrial Processes") & (merged_df["Gas"] == "HFCS"), ISO3] = fc_gas_total
merged_df[(merged_df["Edgar_Subsector"] == "IN - Industrial Processes") & (merged_df["Gas"] == "HFCS")]
# Out:
#    Subsector   Gas          Edgar_Sector            Edgar_Subsector  \
# 54      ippu  HFCS  Industrial Processes  IN - Industrial Processes
#
#     Edgar_Subsector_Synthetic  \
# 54  IN - Industrial Processes
#
#                                                  Vars  \
# 54  emission_co2e_hfcs_ippu_product_use_product_us...
#
#                                   id       LBY
# 54  IN - Industrial Processes - HFCS  4.191501

# %%
# # divide the fc_gas_total between the Industrial Processes NaN rows
# num_of_ippu_nan_rows = merged_df[(merged_df["Edgar_Subsector"] == "IN - Industrial Processes") & (merged_df[ISO3].isna())].shape[0]
# fc_gas_per_row = fc_gas_total / num_of_ippu_nan_rows
# fc_gas_per_row

# %%
# # replace the NaNs in the Industrial Processes rows with the calculated fc_gas_per_row
# merged_df.loc[(merged_df["Edgar_Subsector"] == "IN - Industrial Processes") & (merged_df[ISO3].isna()), ISO3] = fc_gas_per_row

# %%
merged_df[merged_df[ISO3].isna()]
# Out:
#    Subsector        Gas                             Edgar_Sector  \
# 6       ccsq        CH4                                     CCSQ
# 7       ccsq        CO2                                     CCSQ
# 8       ccsq        N2O                                     CCSQ
# 21      scoe        CH4                                   Energy
# 22      scoe        CO2                                   Energy
# 23      scoe        N2O                                   Energy
# 27      ippu       C2F6                     Industrial Processes
# 28      ippu     C2H3F3                     Industrial Processes
# 29      ippu      C2HF5                     Industrial Processes
# 30      ippu       C3F8                     Industrial Processes
# 31      ippu     C3H2F6                     Industrial Processes
# 32      ippu     C3H3F5                     Industrial Processes
# 33      ippu      C3HF7                     Industrial Processes
# 34      ippu      C4F10                     Industrial Processes
# 35      ippu       C4F6                     Industrial Processes
# 36      ippu     C4H5F5                     Industrial Processes
# 37      ippu      C5F12                     Industrial Processes
# 38      ippu       C5F8                     Industrial Processes
# 39      ippu    C5H2F10                     Industrial Processes
# 40      ippu      C6F14                     Industrial Processes
# 41      ippu      CC4F8                     Industrial Processes
# 42      ippu        CF4                     Industrial Processes
# 43      ippu      CH2F2                     Industrial Processes
# 44      ippu   CH2FCHF2                     Industrial Processes
# 45      ippu   CH3CCI2F                     Industrial Processes
# 46      ippu   CH3CCIF2                     Industrial Processes
# 47      ippu    CH3CHF2                     Industrial Processes
# 48      ippu       CH3F                     Industrial Processes
# 50      ippu    CHF2CF3                     Industrial Processes
# 51      ippu   CHF2CHF2                     Industrial Processes
# 52      ippu       CHF3                     Industrial Processes
# 56      ippu  OTHER_FCS                     Industrial Processes
# 57      ippu       PFCS                     Industrial Processes
# 59      lndu        CH4  Land Use, Land Use Change, and Forestry
# 60      lndu        CO2  Land Use, Land Use Change, and Forestry
# 61      frst        CH4  Land Use, Land Use Change, and Forestry
# 62      frst        CO2  Land Use, Land Use Change, and Forestry
# 63      frst        CO2  Land Use, Land Use Change, and Forestry
# 64      frst        CO2  Land Use, Land Use Change, and Forestry
# 65      soil        CO2  Land Use, Land Use Change, and Forestry
# 66      soil        N2O  Land Use, Land Use Change, and Forestry
# 67      lndu        CO2  Land Use, Land Use Change, and Forestry
# 68      ippu        NF3                              UNACCOUNTED
# 70      waso        CO2                                    Waste
# 71      waso        N2O                                    Waste
#
#               Edgar_Subsector           Edgar_Subsector_Synthetic  \
# 6                        CCSQ                                CCSQ
# 7                        CCSQ                                CCSQ
# 8                        CCSQ                                CCSQ
# 21                 EN - Other                          EN - Other
# 22                 EN - Other                          EN - Other
# 23                 EN - Other                          EN - Other
# 27  IN - Industrial Processes           IN - Industrial Processes
# 28  IN - Industrial Processes           IN - Industrial Processes
# 29  IN - Industrial Processes           IN - Industrial Processes
# 30  IN - Industrial Processes           IN - Industrial Processes
# 31  IN - Industrial Processes           IN - Industrial Processes
# 32  IN - Industrial Processes           IN - Industrial Processes
# 33  IN - Industrial Processes           IN - Industrial Processes
# 34  IN - Industrial Processes           IN - Industrial Processes
# 35  IN - Industrial Processes           IN - Industrial Processes
# 36  IN - Industrial Processes           IN - Industrial Processes
# 37  IN - Industrial Processes           IN - Industrial Processes
# 38  IN - Industrial Processes           IN - Industrial Processes
# 39  IN - Industrial Processes           IN - Industrial Processes
# 40  IN - Industrial Processes           IN - Industrial Processes
# 41  IN - Industrial Processes           IN - Industrial Processes
# 42  IN - Industrial Processes           IN - Industrial Processes
# 43  IN - Industrial Processes           IN - Industrial Processes
# 44  IN - Industrial Processes           IN - Industrial Processes
# 45  IN - Industrial Processes           IN - Industrial Processes
# 46  IN - Industrial Processes           IN - Industrial Processes
# 47  IN - Industrial Processes           IN - Industrial Processes
# 48  IN - Industrial Processes           IN - Industrial Processes
# 50  IN - Industrial Processes           IN - Industrial Processes
# 51  IN - Industrial Processes           IN - Industrial Processes
# 52  IN - Industrial Processes           IN - Industrial Processes
# 56  IN - Industrial Processes           IN - Industrial Processes
# 57  IN - Industrial Processes           IN - Industrial Processes
# 59     LULUCF - Deforestation              LULUCF - Deforestation
# 60     LULUCF - Deforestation              LULUCF - Deforestation
# 61       LULUCF - Forest Land                LULUCF - Forest Land
# 62       LULUCF - Forest Land       LULUCF - Forest Land Removals
# 63       LULUCF - Forest Land  LULUCF - Forest Land Sequestration
# 64               LULUCF - HWP                        LULUCF - HWP
# 65      LULUCF - Organic Soil               LULUCF - Organic Soil
# 66      LULUCF - Organic Soil               LULUCF - Organic Soil
# 67        LULUCF - Other Land                 LULUCF - Other Land
# 68                UNACCOUNTED                         UNACCOUNTED
# 70        Waste - Solid Waste                 Waste - Solid Waste
# 71        Waste - Solid Waste                 Waste - Solid Waste
#
#                                                  Vars  \
# 6           emission_co2e_ch4_ccsq_direct_air_capture
# 7           emission_co2e_co2_ccsq_direct_air_capture
# 8           emission_co2e_n2o_ccsq_direct_air_capture
# 21                    emission_co2e_ch4_scoe_other_se
# 22             emission_co2e_co2_scoe_nbmass_other_se
# 23                    emission_co2e_n2o_scoe_other_se
# 27  emission_co2e_c2f6_ippu_product_use_product_us...
# 28  emission_co2e_c2h3f3_ippu_product_use_product_...
# 29  emission_co2e_c2hf5_ippu_product_use_product_u...
# 30  emission_co2e_c3f8_ippu_production_chemicals:e...
# 31  emission_co2e_c3h2f6_ippu_product_use_product_...
# 32  emission_co2e_c3h3f5_ippu_product_use_product_...
# 33  emission_co2e_c3hf7_ippu_product_use_product_u...
# 34  emission_co2e_c4f10_ippu_product_use_product_u...
# 35     emission_co2e_c4f6_ippu_production_electronics
# 36  emission_co2e_c4h5f5_ippu_product_use_product_...
# 37      emission_co2e_c5f12_ippu_production_chemicals
# 38     emission_co2e_c5f8_ippu_production_electronics
# 39  emission_co2e_c5h2f10_ippu_product_use_product...
# 40  emission_co2e_c6f14_ippu_product_use_product_u...
# 41  emission_co2e_cc4f8_ippu_production_chemicals:...
# 42  emission_co2e_cf4_ippu_product_use_product_use...
# 43  emission_co2e_ch2f2_ippu_product_use_product_u...
# 44  emission_co2e_ch2fchf2_ippu_product_use_produc...
# 45  emission_co2e_ch3cci2f_ippu_product_use_produc...
# 46  emission_co2e_ch3ccif2_ippu_product_use_produc...
# 47  emission_co2e_ch3chf2_ippu_product_use_product...
# 48     emission_co2e_ch3f_ippu_production_electronics
# 50  emission_co2e_chf2cf3_ippu_product_use_product...
# 51  emission_co2e_chf2chf2_ippu_product_use_produc...
# 52  emission_co2e_chf3_ippu_product_use_product_us...
# 56  emission_co2e_other_fcs_ippu_product_use_produ...
# 57  emission_co2e_pfcs_ippu_product_use_product_us...
# 59                    emission_co2e_ch4_lndu_wetlands
# 60  emission_co2e_co2_lndu_conversion_forests_mang...
# 61  emission_co2e_ch4_frst_methane_mangroves:emiss...
# 62  emission_co2e_co2_entc_bmass_processing_and_re...
# 63  emission_co2e_co2_frst_sequestration_mangroves...
# 64     emission_co2e_co2_frst_harvested_wood_products
# 65  emission_co2e_co2_soil_lime_use:emission_co2e_...
# 66  emission_co2e_n2o_soil_fertilizer:emission_co2...
# 67  emission_co2e_co2_lndu_conversion_croplands_to...
# 68  emission_co2e_nf3_ippu_production_chemicals:em...
# 70                emission_co2e_co2_waso_incineration
# 71  emission_co2e_n2o_waso_compost_food:emission_c...
#
#                                        id  LBY
# 6                              CCSQ - CH4  NaN
# 7                              CCSQ - CO2  NaN
# 8                              CCSQ - N2O  NaN
# 21                       EN - Other - CH4  NaN
# 22                       EN - Other - CO2  NaN
# 23                       EN - Other - N2O  NaN
# 27       IN - Industrial Processes - C2F6  NaN
# 28     IN - Industrial Processes - C2H3F3  NaN
# 29      IN - Industrial Processes - C2HF5  NaN
# 30       IN - Industrial Processes - C3F8  NaN
# 31     IN - Industrial Processes - C3H2F6  NaN
# 32     IN - Industrial Processes - C3H3F5  NaN
# 33      IN - Industrial Processes - C3HF7  NaN
# 34      IN - Industrial Processes - C4F10  NaN
# 35       IN - Industrial Processes - C4F6  NaN
# 36     IN - Industrial Processes - C4H5F5  NaN
# 37      IN - Industrial Processes - C5F12  NaN
# 38       IN - Industrial Processes - C5F8  NaN
# 39    IN - Industrial Processes - C5H2F10  NaN
# 40      IN - Industrial Processes - C6F14  NaN
# 41      IN - Industrial Processes - CC4F8  NaN
# 42        IN - Industrial Processes - CF4  NaN
# 43      IN - Industrial Processes - CH2F2  NaN
# 44   IN - Industrial Processes - CH2FCHF2  NaN
# 45   IN - Industrial Processes - CH3CCI2F  NaN
# 46   IN - Industrial Processes - CH3CCIF2  NaN
# 47    IN - Industrial Processes - CH3CHF2  NaN
# 48       IN - Industrial Processes - CH3F  NaN
# 50    IN - Industrial Processes - CHF2CF3  NaN
# 51   IN - Industrial Processes - CHF2CHF2  NaN
# 52       IN - Industrial Processes - CHF3  NaN
# 56  IN - Industrial Processes - OTHER_FCS  NaN
# 57       IN - Industrial Processes - PFCS  NaN
# 59           LULUCF - Deforestation - CH4  NaN
# 60           LULUCF - Deforestation - CO2  NaN
# 61             LULUCF - Forest Land - CH4  NaN
# 62             LULUCF - Forest Land - CO2  NaN
# 63             LULUCF - Forest Land - CO2  NaN
# 64                     LULUCF - HWP - CO2  NaN
# 65            LULUCF - Organic Soil - CO2  NaN
# 66            LULUCF - Organic Soil - N2O  NaN
# 67              LULUCF - Other Land - CO2  NaN
# 68                      UNACCOUNTED - NF3  NaN
# 70              Waste - Solid Waste - CO2  NaN
# 71              Waste - Solid Waste - N2O  NaN

# %%
merged_df[ISO3] = merged_df[ISO3].fillna(0)
merged_df.isna().sum()
# Out:
# Subsector                    0
# Gas                          0
# Edgar_Sector                 0
# Edgar_Subsector              0
# Edgar_Subsector_Synthetic    0
# Vars                         0
# id                           0
# LBY                          0
# dtype: int64

# %%
print("Original inventory total:", inventory_region_year_df[ISO3].sum())
print("Merged dataframe total:", merged_df[ISO3].sum())
# Out:
# Original inventory total: 104.513880277
# Merged dataframe total: 106.42346668999998

# %% [markdown]
# ## Fix discrepancies between totals in original inventory and merged inventory

# %%
duplicated_ids.head()
# Out:
#    Subsector  Gas                             Edgar_Sector  \
# 3       lvst  CH4                              Agriculture
# 4       lsmm  CH4                              Agriculture
# 62      frst  CO2  Land Use, Land Use Change, and Forestry
# 63      frst  CO2  Land Use, Land Use Change, and Forestry
#
#          Edgar_Subsector           Edgar_Subsector_Synthetic  \
# 3         AG - Livestock                      AG - Livestock
# 4         AG - Livestock                      AG - Livestock
# 62  LULUCF - Forest Land       LULUCF - Forest Land Removals
# 63  LULUCF - Forest Land  LULUCF - Forest Land Sequestration
#
#                                                  Vars  \
# 3   emission_co2e_ch4_lvst_entferm_buffalo:emissio...
# 4   emission_co2e_ch4_lsmm_anaerobic_digester:emis...
# 62  emission_co2e_co2_entc_bmass_processing_and_re...
# 63  emission_co2e_co2_frst_sequestration_mangroves...
#
#                             id       LBY
# 3         AG - Livestock - CH4  1.909586
# 4         AG - Livestock - CH4  1.909586
# 62  LULUCF - Forest Land - CO2       NaN
# 63  LULUCF - Forest Land - CO2       NaN

# %%
duplicated_ids.id.unique()
# Out:
# array(['AG - Livestock - CH4', 'LULUCF - Forest Land - CO2'], dtype=object)

# %%
merged_df[merged_df.id.isin(duplicated_ids.id.unique())]
# Out:
#    Subsector  Gas                             Edgar_Sector  \
# 3       lvst  CH4                              Agriculture
# 4       lsmm  CH4                              Agriculture
# 62      frst  CO2  Land Use, Land Use Change, and Forestry
# 63      frst  CO2  Land Use, Land Use Change, and Forestry
#
#          Edgar_Subsector           Edgar_Subsector_Synthetic  \
# 3         AG - Livestock                      AG - Livestock
# 4         AG - Livestock                      AG - Livestock
# 62  LULUCF - Forest Land       LULUCF - Forest Land Removals
# 63  LULUCF - Forest Land  LULUCF - Forest Land Sequestration
#
#                                                  Vars  \
# 3   emission_co2e_ch4_lvst_entferm_buffalo:emissio...
# 4   emission_co2e_ch4_lsmm_anaerobic_digester:emis...
# 62  emission_co2e_co2_entc_bmass_processing_and_re...
# 63  emission_co2e_co2_frst_sequestration_mangroves...
#
#                             id       LBY
# 3         AG - Livestock - CH4  1.909586
# 4         AG - Livestock - CH4  1.909586
# 62  LULUCF - Forest Land - CO2  0.000000
# 63  LULUCF - Forest Land - CO2  0.000000

# %%
# Since we had duplicated ids in the crosswalk, we need to distribute the emissions values equally among the duplicated rows
lvst_ch4_value = merged_df[(merged_df["Subsector"] == "lvst") & (merged_df["Gas"] == "CH4")][ISO3].values[0]
lvst_ch4_value
# Out:
# np.float64(1.909586413)

# %%
value_to_distribute = lvst_ch4_value / 2
value_to_distribute
# Out:
# np.float64(0.9547932065)

# %%
# Update values
merged_df.loc[merged_df.id == "AG - Livestock - CH4", ISO3] = value_to_distribute

# %%
merged_df[merged_df.id.isin(duplicated_ids.id.unique())]
# Out:
#    Subsector  Gas                             Edgar_Sector  \
# 3       lvst  CH4                              Agriculture
# 4       lsmm  CH4                              Agriculture
# 62      frst  CO2  Land Use, Land Use Change, and Forestry
# 63      frst  CO2  Land Use, Land Use Change, and Forestry
#
#          Edgar_Subsector           Edgar_Subsector_Synthetic  \
# 3         AG - Livestock                      AG - Livestock
# 4         AG - Livestock                      AG - Livestock
# 62  LULUCF - Forest Land       LULUCF - Forest Land Removals
# 63  LULUCF - Forest Land  LULUCF - Forest Land Sequestration
#
#                                                  Vars  \
# 3   emission_co2e_ch4_lvst_entferm_buffalo:emissio...
# 4   emission_co2e_ch4_lsmm_anaerobic_digester:emis...
# 62  emission_co2e_co2_entc_bmass_processing_and_re...
# 63  emission_co2e_co2_frst_sequestration_mangroves...
#
#                             id       LBY
# 3         AG - Livestock - CH4  0.954793
# 4         AG - Livestock - CH4  0.954793
# 62  LULUCF - Forest Land - CO2  0.000000
# 63  LULUCF - Forest Land - CO2  0.000000

# %%
print("Original inventory total:", inventory_region_year_df[ISO3].sum())
print("Merged dataframe total:", merged_df[ISO3].sum())
# Out:
# Original inventory total: 104.513880277
# Merged dataframe total: 104.51388027699998

# %% [markdown]
# ## Double check IPPU

# %%
inventory_region_year_df[inventory_region_year_df["CSC Subsector"] == "IN - Industrial Processes"]
# Out:
#      Code              CSC Subsector  Gas       LBY  \
# 3077  LBY  IN - Industrial Processes  CH4  0.003465
# 3078  LBY  IN - Industrial Processes  CO2  2.499458
# 3079  LBY  IN - Industrial Processes  HFC  4.191501
# 3080  LBY  IN - Industrial Processes  N2O  0.360349
# 3081  LBY  IN - Industrial Processes  SF6  0.560506
#
#                                    id
# 3077  IN - Industrial Processes - CH4
# 3078  IN - Industrial Processes - CO2
# 3079  IN - Industrial Processes - HFC
# 3080  IN - Industrial Processes - N2O
# 3081  IN - Industrial Processes - SF6

# %%
merged_df[(merged_df["Edgar_Subsector"] == "IN - Industrial Processes") & (~merged_df["Gas"].isin(["CH4", "CO2", "N2O", "SF6"]))][ISO3].sum()
# Out:
# np.float64(4.191500967)

# %%
merged_df[(merged_df["Edgar_Subsector"] == "IN - Industrial Processes") & (merged_df["Gas"].isin(["CH4", "CO2", "N2O", "SF6"]))][ISO3]
# Out:
# 49    0.003465
# 53    2.499458
# 55    0.360349
# 58    0.560506
# Name: LBY, dtype: float64

# %% [markdown]
# ## Save

# %%
merged_df["Edgar_Class"] = merged_df["Edgar_Subsector"] + ":" +merged_df["Gas"] 
merged_df.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  CH4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  CO2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  N2O  Agriculture      AG - Crops                AG - Crops
# 3      lvst  CH4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  CH4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars                    id  \
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...      AG - Crops - CH4
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...      AG - Crops - CO2
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...      AG - Crops - N2O
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  AG - Livestock - CH4
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  AG - Livestock - CH4
#
#         LBY         Edgar_Class
# 0  0.000293      AG - Crops:CH4
# 1  0.015880      AG - Crops:CO2
# 2  0.759204      AG - Crops:N2O
# 3  0.954793  AG - Livestock:CH4
# 4  0.954793  AG - Livestock:CH4

# %%
merged_df.to_csv(os.path.join(OUTPUT_DIR_PATH, f"emission_targets_{REGION}_{YEAR}.csv"), index=False)
